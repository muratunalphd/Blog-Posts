# %%
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
import numpy as np
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)
pd.set_option('display.max_colwidth', None)
from plotnine import *
from tqdm import tqdm
from joblib import Parallel, delayed # for parallel processing
import statsmodels.formula.api as smf

# %%
def dgp(n=2000, p=10, linear=True, constant=True):
        
    Xmat = np.random.multivariate_normal(np.zeros(p), np.eye(p), size=n).astype('float32')

    T = np.random.binomial(1, 0.5, n).astype('int8')

    col_list = ['X' + str(x) for x in range(1,(p+1))]

    df = pd.DataFrame(Xmat, columns = col_list)
    
    # functional form of the covariates
    if linear:
        B = 225 + 50*df['X1'] + 5*df['X2'] + 20*(df['X3']-0.5) + 10*df['X4'] + 5*df['X5']
    else:
        B = 225 + 50*df['X1'] + 5*np.sin(np.pi*df['X1']*df['X2'] ) + 10*(df['X3']-0.5)**2 + 10*df['X4']**2 + 5*df['X5']**3
    
    # constant ate or non-constant
    tau = 5 if constant else 5*df['X1'] + 5*np.log(1 + np.exp(df['X2']))
    
    Y = (B + tau*T + np.random.normal(0,25,n)).astype('float32')
        
    df['T'] = T
    df['Y'] = Y
    df['tau'] = tau
    
    return df

# %%
# print(np.iinfo('int8'))
# print(np.finfo('float16'))

# %%
data = dgp()
#Memory
print(data.memory_usage(deep=True).sum() )
#Correlations
print(data[['Y','X1','X2','X3','X4','X5','T']].corr()['Y'])
print(data['Y'].describe())
# Out:
# 106128
# Y     1.000000
# X1    0.831637
# X2    0.058259
# X3    0.319390
# X4    0.156082
# X5    0.090726
# T    -0.002708
# Name: Y, dtype: float64
# count    2000.000000
# mean      218.247299
# std        60.718437
# min         2.512698
# 25%       177.053844
# 50%       218.318863
# 75%       258.881752
# max       431.194244
# Name: Y, dtype: float64

# %%
#Test Difference-in-Means
# data = dgp(n=2000, p=10, linear=True, constant=True)
ols = smf.ols('Y ~ T', data = data).fit(cov_type='HC1',use_t=True)


ols.summary().tables[1]
# print(ols.params['T'])
# print([ols.params['T'] - 1.96*ols.bse['T'] ] )
# print( [ols.params['T'] + 1.96*ols.bse['T'] ])
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
print(data['Y'].describe())
# Out:
# count    2000.000000
# mean      214.203522
# std        59.669521
# min        19.274212
# 25%       175.542225
# 50%       216.274391
# 75%       253.902962
# max       436.681335
# Name: Y, dtype: float64

# %%
data['Tplot'] = data['T'] + np.random.normal(0, 0.01, size=len(data["Y"]))
(ggplot(data, aes(x='Tplot', y='Y'))+
 geom_point(color='c')+
 ylab("Spending Amount ($)") + 
 xlab("Received Coupon")+
 theme(figure_size=(10, 8)) +
  theme(axis_text_x = element_text(angle = 0, hjust = 1))
)
# Out:
# <ggplot: (719112964)>

# %%
model_t = smf.ols('T ~ ' + ('+').join(data.columns.tolist()[0:10]), data=data).fit(cov_type='HC1',use_t=True)
model_y = smf.ols('Y ~ ' + ('+').join(data.columns.tolist()[0:10]), data=data).fit(cov_type='HC1',use_t=True)

residuals = pd.DataFrame(dict(res_y=model_y.resid, res_t=model_t.resid))

model_res = smf.ols('res_y ~ res_t', data=residuals).fit()

# %%
print("Y Variance", round(np.var(data["Y"]),2))
print("Y Residual Variance", round(np.var(residuals["res_y"]),2))

print("T Variance", round(np.var(data["T"]),2))
print("T Residual Variance", round(np.var(residuals["res_t"]),2))

model_res.summary().tables[1]
# Out:
# Y Variance 3558.67
# Y Residual Variance 605.9
# T Variance 0.25
# T Residual Variance 0.25
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
ols = smf.ols('Y ~' + ('+').join(data.columns.tolist()[0:(p+1)]),
                 data = data).fit(cov_type='HC1',use_t=True)

print(ols.summary().tables[1])
# Out:
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    214.2436      0.770    278.119      0.000     212.733     215.754
# X1            49.9696      0.582     85.856      0.000      48.828      51.111
# X2             5.3290      0.548      9.725      0.000       4.254       6.404
# X3            19.3870      0.570     34.040      0.000      18.270      20.504
# X4            11.2194      0.546     20.534      0.000      10.148      12.291
# X5             4.1985      0.550      7.640      0.000       3.121       5.276
# X6             0.8823      0.555      1.589      0.112      -0.206       1.971
# X7            -0.5683      0.565     -1.006      0.314      -1.676       0.540
# X8             0.0040      0.553      0.007      0.994      -1.081       1.089
# X9             0.3943      0.537      0.734      0.463      -0.660       1.448
# ...

# %%
residuals['Tplot'] = data['Tplot']
(ggplot(residuals, aes(x='Tplot', y='res_y'))+
 geom_point(color='c') + 
 ylab("Spending Amount ($)") +
 xlab("Received Coupon")
)
# Out:
# <ggplot: (719155637)>

# %%
data = dgp(n=1000, p=10, linear=True, constant=False)
data = data.assign(**({c+'tilde': (data[c] - data[c].mean()) for c in data.columns.tolist()[0:10]}))
data.head()
# Out:
#          X1        X2        X3        X4        X5        X6        X7  \
# 0  0.223650 -1.277679 -1.045751  1.173440  0.172996 -1.707006 -0.841697
# 1  1.667187  0.646501 -0.252719 -0.968037  1.121001 -0.597467 -0.553049
# 2 -0.834063  1.391367  2.854413  0.791074 -1.035383  0.041819 -1.072552
# 3 -0.077696  1.109042 -0.481066  1.779942 -1.556743 -0.538234 -0.542573
# 4 -0.420359 -0.472740  0.059570 -0.254493  0.743717 -1.611371  0.693173
#
#          X8        X9       X10  T           Y        tau   X1tilde   X2tilde  \
# 0 -0.899477 -1.421688 -0.774603  1   99.969681   2.347405  0.234627 -1.280150
# 1  0.360856 -0.807767  1.554226  1  124.172363  13.674725  1.678164  0.644031
# 2 -1.049825 -0.397629  1.424999  1  125.805992   3.897177 -0.823085  1.388896
# 3  0.618855  1.333322  0.139571  0   85.558372   6.582153 -0.066719  1.106572
# 4  0.857318 -0.920260 -0.926563  1   66.719627   0.320489 -0.409381 -0.475210
#
# ...

# %%
#Test OLS
p=10
ols = smf.ols('Y ~' + ('+').join(data.columns.tolist()[0:(p+1)]) + '+' + 'T:('+('+').join(data.columns.tolist()[p+3:])+')',
                 data = data).fit(cov_type='HC1',use_t=True)

print(ols.summary().tables[1])
# print(ols.params['T'])
# print([ols.params['T'] - 1.96*ols.bse['T'] ] )
# print( [ols.params['T'] + 1.96*ols.bse['T'] ])
# Out:
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     90.7070      1.133     80.032      0.000      88.483      92.931
# X1            49.9393      1.138     43.898      0.000      47.707      52.172
# X2             6.5623      1.096      5.989      0.000       4.412       8.713
# X3            20.7676      1.256     16.537      0.000      18.303      23.232
# X4            10.0372      1.016      9.883      0.000       8.044      12.030
# X5             3.2160      1.131      2.844      0.005       0.997       5.435
# X6            -0.7356      1.016     -0.724      0.469      -2.730       1.259
# X7            -0.3886      1.199     -0.324      0.746      -2.742       1.965
# X8             0.1699      1.223      0.139      0.890      -2.229       2.569
# X9            -1.3064      1.131     -1.155      0.248      -3.525       0.913
# ...

# %% [markdown]
# ## Effect Heterogenetiy: Constant vs Varying Effect

# %%
(ggplot(data, aes(y=data['X2'],x=data['X1'], color=data['tau']))+
 geom_point()
)

# %% [markdown]
# ## Set Up Experiment

# %%
# %%time
import warnings
warnings.filterwarnings("ignore") 
from xgboost import XGBRegressor
from sklearn.model_selection import StratifiedKFold

def mlpredict(dfml,p):
    XGB_reg = XGBRegressor(learning_rate = 0.3, 
                            max_depth = 10, 
                            n_estimators = 500, 
                            reg_lambda = 1, nthread=-1)

    
    X_mat = dfml.columns.tolist()[0:p]
    
    kfold = StratifiedKFold(n_splits=2, shuffle=True, random_state=1)

    ix = []
    Yhat = []
    for train_index, test_index in kfold.split(dfml, dfml["T"]):
        
        df_train = dfml.iloc[train_index].reset_index()
        df_test = dfml.iloc[test_index].reset_index()

        X_train = df_train[X_mat].copy()
        y_train = df_train['Y'].copy()
        X_test =  df_test[X_mat].copy()
        # y_test = df_test['Y'].copy()
        XGB_reg.fit(X_train, y_train)

        Y_hat = XGB_reg.predict(X_test)

        ix.extend(list(test_index))
        Yhat.extend(list(Y_hat))

    df_ml = pd.DataFrame({'ix':ix,'Yhat':Yhat}).sort_values(by='ix').reset_index(drop=True)
    df_ml[['Y','T']] = dfml[['Y','T']]
    df_ml['Ytilde'] = df_ml['Yhat'] - np.mean(df_ml['Yhat'])
    df_ml['Yres'] = df_ml['Y'] - df_ml['Yhat']
    df_ml = df_ml.drop('ix', axis=1)

    return df_ml
# Out:
# CPU times: user 38 µs, sys: 2 µs, total: 40 µs
# Wall time: 46.3 µs

# %%
def experiment(**kwargs):
    
    dct = {}
    
    n = kwargs['n']
    p = kwargs['p']
    
    df = dgp(n,p,kwargs['linear'],kwargs['constant'])
    
    #1. Difference-in-means
    mu_treated = np.mean(df.query('T==1')['Y'])
    mu_control = np.mean(df.query('T==0')['Y'])
    
    dct['DIM'] = mu_treated - mu_control
    
    #2. OLS adjusted
    if kwargs['OLS_adj']:
        
        ols_adj = smf.ols('Y ~' + ('+').join(df.columns.tolist()[0:(p+1)]),
                 data = df).fit(cov_type='HC1',use_t=True)

        dct['OLS_adj'] = ols_adj.params['T']
    
    #3. OLS interacted
    if kwargs['OLS_int']:
        df = df.assign(**({c+'tilde': (df[c] - df[c].mean()) for c in df.columns.tolist()[0:p]}))
    
        ols_int = smf.ols('Y ~' + ('+').join(df.columns.tolist()[0:(p+1)]) + '+' + 'T:('+('+').join(df.columns.tolist()[p+2:])+')',
                 data = df).fit(cov_type='HC1',use_t=True)

        dct['OLS_int'] = ols_int.params['T']
    
    #4. CUPED: Single Covariate 
    if kwargs['CUPED_s']:
        theta = smf.ols('Y ~ X1',data = df).fit(cov_type='HC1',use_t=True).params['X1']

        df['Y_res'] = df['Y'] - theta*(df['X1'] - np.mean(df['X1']))
        
        cuped_s = smf.ols('Y_res ~ T', data=df).fit(cov_type='HC1',use_t=True)

        dct['CUPED_s'] = cuped_s.params['T']
        
    #4. CUPED: Multiple Covariates 
    if kwargs['CUPED_m']:
        df['Y_res'] = smf.ols('Y ~' + ('+').join(df.columns.tolist()[0:p]),
                     data = df).fit(cov_type='HC1',use_t=True).resid + np.mean(df['Y'])
        
        cuped_m = smf.ols('Y_res ~ T', data=df).fit(cov_type='HC1',use_t=True)

        dct['CUPED_m'] = cuped_m.params['T']   
    
    pred_df = mlpredict(df,p)

    #5. Difference-in-differences
    if kwargs['DID']:
        mu2_treated = np.mean(pred_df.query('T==1')['Yres'])
        mu2_control = np.mean(pred_df.query('T==0')['Yres'])

        dct['DID'] = mu2_treated - mu2_control

    #6. MLRATE
    if kwargs['MLRATE']:
        mlrate = ols = smf.ols('Y ~ T + Yhat + T:Ytilde',
                     data = pred_df).fit(cov_type='HC1',use_t=True)

        dct['MLRATE'] = mlrate.params['T']
    
    return dct

# %%
def plot_experiment(results, constant = True ):
    
    results_long = pd.melt(results, value_vars=results.columns.tolist() )
    
    print(round(results_long.groupby('variable').agg(mean=("value", "mean"), std=("value", "std"))
          .reset_index().sort_values(by='std', ascending=False).reset_index(drop=True)
          .assign(CI_lower= lambda x: x['mean'] - x['std']*1.96,
                CI_upper= lambda x: x['mean'] + x['std']*1.96,),3)
         )
        
    mu = 5 if constant else 4
    
    p = (ggplot(results_long, aes(x='value',color='variable') ) + 
     geom_density(size=1 )+
     # coord_flip()+    
     # scale_linetype_manual(values = ['solid', 'solid','dotted', 'dotted', 'solid', 'dashed','dashed']) + 
     scale_color_manual(values = ['black', 'blue', 'green', 'c','red', 'salmon', 'magenta' ]) + 
     geom_vline(xintercept=mu, colour='black', linetype='dashed' ) + 
     annotate("text", x=mu, y=.1, label="True Mean", size=15)+
     labs(color='Method')  +
     xlab('Estimate') +
     theme(figure_size=(16, 12))
    )
    
    print(p)

# %% [markdown]
# ## Linear Effects of Covariates & Constant Treatment Effect

# %%
# %%time
tqdm._instances.clear() 
sim = 1000

results1 = Parallel(n_jobs=8)(delayed(experiment)(n=2000, p=10, linear=True, constant=True,
                                    OLS_adj=True, OLS_int=True, CUPED_s=True, CUPED_m=True, DID=True, MLRATE=True)\
                                    for _ in tqdm(range(sim)) )

results_df1 = pd.DataFrame(results1)

plot_experiment(results_df1)
# Out:
# 100%|███████████████████████████████████████| 1000/1000 [01:38<00:00, 10.17it/s]
#   variable   mean    std  CI_lower  CI_upper
# 0      DIM  4.932  2.733    -0.426    10.289
# 1  CUPED_s  5.022  1.522     2.038     8.005
# 2      DID  4.995  1.350     2.349     7.641
# 3   MLRATE  4.994  1.346     2.357     7.632
# 4  OLS_adj  5.036  1.098     2.883     7.188
# 5  OLS_int  5.036  1.098     2.883     7.188
# 6  CUPED_m  5.011  1.093     2.869     7.153
# CPU times: user 6.91 s, sys: 294 ms, total: 7.2 s
# Wall time: 1min 40s

# %% [markdown]
# ## Linear Effects of Covariates & Varying Treatment Effect

# %%
# %%time
tqdm._instances.clear() 
sim = 1000

results2 = Parallel(n_jobs=8)(delayed(experiment)(n=2000, p=10,linear=True, constant=False,
                                    OLS_adj=True, OLS_int=True, CUPED_s=True, CUPED_m=True, DID=True, MLRATE=True)\
                                    for _ in tqdm(range(sim)) )

results_df2 = pd.DataFrame(results2)

plot_experiment(results_df2, False)
# Out:
# 100%|███████████████████████████████████████| 1000/1000 [01:37<00:00, 10.21it/s]
#   variable   mean    std  CI_lower  CI_upper
# 0      DIM  4.083  2.768    -1.342     9.509
# 1  CUPED_s  4.041  1.554     0.994     7.088
# 2      DID  4.052  1.378     1.352     6.753
# 3   MLRATE  4.055  1.374     1.362     6.749
# 4  OLS_adj  4.041  1.124     1.837     6.244
# 5  OLS_int  4.041  1.124     1.839     6.244
# 6  CUPED_m  4.020  1.119     1.828     6.213
# CPU times: user 7.14 s, sys: 269 ms, total: 7.41 s
# Wall time: 1min 39s

# %% [markdown]
# ## Non-Linear Effects of Covariates & Constant Treatment Effect

# %%
# %%time
tqdm._instances.clear() 
sim = 1000

results3 = Parallel(n_jobs=8)(delayed(experiment)(n=2000, p=10,linear=False, constant=True,
                                    OLS_adj=True, OLS_int=True, CUPED_s=True, CUPED_m=True, DID=True, MLRATE=True)\
                                    for _ in tqdm(range(sim)) )

results_df3 = pd.DataFrame(results3)

plot_experiment(results_df3)
# Out:
# 100%|███████████████████████████████████████| 1000/1000 [01:46<00:00,  9.39it/s]
#   variable   mean    std  CI_lower  CI_upper
# 0      DIM  5.051  2.683    -0.207    10.309
# 1  CUPED_s  5.013  1.726     1.630     8.397
# 2  OLS_int  5.047  1.473     2.160     7.933
# 3  OLS_adj  5.047  1.472     2.162     7.932
# 4  CUPED_m  5.022  1.465     2.150     7.893
# 5      DID  4.987  1.449     2.146     7.828
# 6   MLRATE  4.991  1.443     2.163     7.818
# CPU times: user 7.08 s, sys: 1.43 s, total: 8.51 s
# Wall time: 1min 48s

# %% [markdown]
# ## Non-Linear Effects of Covariates & Varying Treatment Effect

# %%
# %%time
tqdm._instances.clear() 
sim = 1000

results4 = Parallel(n_jobs=8)(delayed(experiment)(n=2000, p=10,linear=False, constant=False,
                             OLS_adj=True, OLS_int=True, CUPED_s=True,CUPED_m=True,DID=True,MLRATE=True)\
                             for _ in tqdm(range(sim)) )

results_df4 = pd.DataFrame(results4)

plot_experiment(results_df4, False)
# Out:
# 100%|███████████████████████████████████████| 1000/1000 [01:46<00:00,  9.41it/s]
#   variable   mean    std  CI_lower  CI_upper
# 0      DIM  4.101  2.869    -1.523     9.726
# 1  CUPED_s  4.057  1.793     0.542     7.571
# 2  OLS_adj  4.044  1.586     0.936     7.153
# 3  OLS_int  4.044  1.586     0.936     7.152
# 4  CUPED_m  4.024  1.578     0.931     7.117
# 5      DID  4.025  1.488     1.110     6.941
# 6   MLRATE  4.028  1.485     1.117     6.938
# CPU times: user 6.56 s, sys: 300 ms, total: 6.86 s
# Wall time: 1min 48s

# %%
(6.938 - 1.117)/(7.152-0.936)
# Out:
# 0.9364543114543114

# %% [markdown]
# ## OLS Mathematics

# %% [markdown]
# > $\beta_1 = Cov(Y,x)/Var(x)$

# %%
data[['Y','T']].cov()['Y']['T']/np.var(data['T'])

# %% [markdown]
# > $\beta_k = Cov(Y,\tilde x_{k})/Var(\tilde x_k)$
#
# > where $\tilde x_k$ is the residual from a regression of $x_k$ on all the other covariates
#
# > each coef. in a multivariate regression is the bivariate slope coef. for the corresponding regressor after partialling out all the other covariates.

# %%
data['model_t_res'] = smf.ols('T ~ ' + ('+').join(data.columns.tolist()[0:40]), data=data).fit(cov_type='HC1',use_t=True).resid
data[['Y','model_t_res']].cov()['Y']['model_t_res']/np.var(data['model_t_res'])

# %%
 data['Tplot'] = data['T'] + np.random.normal(0, 0.01, size=len(data["Y"]))
(ggplot(data, aes(x='Tplot', y='Y'))+
 geom_point(color='c')+
 ylab("Spending Amount ($)") + 
 xlab("Received Coupon")
)

# %%
print("Difference in means:",
      data.query("T==1")["Y"].mean() - data.query("T==0")["Y"].mean())

DIM = smf.ols('Y ~ T', data=data).fit(cov_type='HC1',use_t=True)
DIM.summary().tables[1]

# %%
ols = smf.ols('Y ~' +('+').join(data.columns.tolist()[0:41]),data = data).fit(cov_type='HC1',use_t=True)

print(ols.params['T'])
print([ols.params['T'] - 1.96*ols.bse['T'] ] )
print( [ols.params['T'] + 1.96*ols.bse['T'] ])

# %%
# help('joblib')

# %%
data = dgp(linear=False)
data[['Y','T']].cov()

# %% [markdown]
# $\beta_1 = Cov(Y,x)/Var(x)$

# %%
data[['Y','T']].cov()['Y']['T']/np.var(data['T'])

# %% [markdown]
# $\beta_k = Cov(Y,\tilde x_{k})/Var(\tilde x_k)$
#
# > where $\tilde x_k$ is the residual from a regression of $x_k$ on all the other covariates
#
# > each coef. in a multivariate regression is the bivariate slope coef. for the corresponding regressor after partialling out all the other covariates.

# %%
data['model_t_res'] = smf.ols('T ~ ' + ('+').join(data.columns.tolist()[0:40]), data=data).fit(cov_type='HC1',use_t=True).resid
data[['Y','model_t_res']].cov()['Y']['model_t_res']/np.var(data['model_t_res'])

# %%
 data['Tplot'] = data['T'] + np.random.normal(0, 0.01, size=len(data["Y"]))
(ggplot(data, aes(x='Tplot', y='Y'))+
 geom_point(color='c')+
 ylab("Spending Amount ($)") + 
 xlab("Received Coupon")
)

# %%
print("Difference in means:",
      data.query("T==1")["Y"].mean() - data.query("T==0")["Y"].mean())

DIM = smf.ols('Y ~ T', data=data).fit(cov_type='HC1',use_t=True)
DIM.summary().tables[1]

# %%
ols = smf.ols('Y ~' +('+').join(data.columns.tolist()[0:41]),data = data).fit(cov_type='HC1',use_t=True)

print(ols.params['T'])
print([ols.params['T'] - 1.96*ols.bse['T'] ] )
print( [ols.params['T'] + 1.96*ols.bse['T'] ])

# %%
model_t = smf.ols('T ~ ' + ('+').join(data.columns.tolist()[0:40]), data=data).fit(cov_type='HC1',use_t=True)
model_y = smf.ols('Y ~ ' + ('+').join(data.columns.tolist()[0:40]), data=data).fit(cov_type='HC1',use_t=True)

residuals = pd.DataFrame(dict(res_y=model_y.resid, res_t=model_t.resid))

model_res = smf.ols('res_y ~ res_t', data=residuals).fit()

# %%
print("Y Variance", np.var(data["Y"]))
print("Y Residual Variance", np.var(residuals["res_y"]))

print("T Variance", np.var(data["T"]))
print("T Residual Variance", np.var(residuals["res_t"]))

model_res.summary().tables[1]

# %%
residuals['Tplot'] = data['Tplot']
(ggplot(residuals, aes(x='Tplot', y='res_y'))+
 geom_point(color='c') + 
 ylab("Spending Amount ($)") +
 xlab("Received Coupon")
)
